# %%
import pandas as pd

# %%
df = pd.read_csv("ChildObservation_MasterFile.csv")

# %%
df[df['text'].str.contains("police")]

## uncomment below to print indices of rows containing specific string
# new_df = df[df['text'].str.contains("police")]
# for i in new_df['Index']:
    # print(i)
# Out:
#       Index                Page  TargetPerson                      Location  \
# 130     130                 193           293              Behind House 102
# 301     301                 399           116           In front of House 4
# 340     340  471, 472 (missing)           229  Yard in front of House 15-17
# 401     401            622, 623           370  Ditch by corner of House 117
# 455     455                 577           370   Rice field behind House 113
# 504     504                 674           449            Front of House 116
# 648     648            899, 900           404                  In House 102
# 794     794          1127, 1128            58              Front of House 4
# 800     800          1112, 1113           194               Inside House 18
# 802     802                1126             7                       House 1
# 1013   1013          1333, 1334            65                    By House 3
# ...

# %%
# Out:
# 130
# 301
# 340
# 401
# 455
# 504
# 648
# 794
# 800
# 802
# 1013
# 1203
# 1255
# 1464
# 1567
